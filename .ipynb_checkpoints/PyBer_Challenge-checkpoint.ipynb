# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# File to Load (Remember to change these)
city_data_to_load = "./Resources/city_data.csv"
ride_data_to_load = "./Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)
# Out:
# C:\Users\kaitl\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#view the city_data_df
city_data_df
# Out:
#                  city  driver_count   type  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         Richardfort          38.0  Urban         NaN         NaN      2973.0
# 1        Williamsstad          59.0  Urban         NaN         NaN         NaN
# 2         Port Angela          67.0  Urban         NaN         NaN         NaN
# 3          Rodneyfort          34.0  Urban         NaN         NaN         NaN
# 4         West Robert          39.0  Urban         NaN         NaN         NaN
# ...               ...           ...    ...         ...         ...         ...
# 1048570           NaN           NaN    NaN         NaN         NaN         NaN
# 1048571           NaN           NaN    NaN         NaN         NaN         NaN
# 1048572           NaN           NaN    NaN         NaN         NaN         NaN
# 1048573           NaN           NaN    NaN         NaN         NaN         NaN
# 1048574           NaN        5946.0    NaN         NaN         NaN         NaN
#
# [1048575 rows x 6 columns]

# %%
#look for missing data
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          120 non-null    object
#  1   driver_count  122 non-null    float64
#  2   type          120 non-null    object
#  3   Unnamed: 3    0 non-null      float64
#  4   Unnamed: 4    0 non-null      float64
#  5   Unnamed: 5    1 non-null      float64
# dtypes: float64(4), object(2)
# memory usage: 48.0+ MB

# %%
#remove NaN values
clean_city_data_df = city_data_df.dropna(axis=1, how="all")
clean_city_data_df
# Out:
#                  city  driver_count   type  Unnamed: 5
# 0         Richardfort          38.0  Urban      2973.0
# 1        Williamsstad          59.0  Urban         NaN
# 2         Port Angela          67.0  Urban         NaN
# 3          Rodneyfort          34.0  Urban         NaN
# 4         West Robert          39.0  Urban         NaN
# ...               ...           ...    ...         ...
# 1048570           NaN           NaN    NaN         NaN
# 1048571           NaN           NaN    NaN         NaN
# 1048572           NaN           NaN    NaN         NaN
# 1048573           NaN           NaN    NaN         NaN
# 1048574           NaN        5946.0    NaN         NaN
#
# [1048575 rows x 4 columns]

# %%
#how many types are there
clean_city_data_df['type'].value_counts()
# Out:
# Urban       66
# Suburban    36
# Rural       18
# Name: type, dtype: int64

# %%
#clean the ride data of null values
clean_ride_data_df = ride_data_df.dropna(axis=1, how="all", thresh=2, subset=[5,6])

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(clean_ride_data_df, clean_city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.740000e+12           5.0
# 1  South Michelleport   3/4/2019 18:24  30.24  2.340000e+12          72.0
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.010000e+12          57.0
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.150000e+12          34.0
# 4          South Jack    3/6/2019 4:28  34.58  3.910000e+12          46.0
#
#     type  Unnamed: 5
# 0  Urban         NaN
# 1  Urban         NaN
# 2  Urban         NaN
# 3  Urban         NaN
# 4  Urban         NaN

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides_by_type = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_rides_by_type
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
suburban_cities_df = clean_city_data_df[clean_city_data_df["type"] == "Suburban"]
suburban_cities_df.head()
# Out:
#            city  driver_count      type  Unnamed: 5
# 66   Port Shane           7.0  Suburban         NaN
# 67     Lake Ann           3.0  Suburban         NaN
# 68   Lake Scott          23.0  Suburban         NaN
# 69  Colemanland          23.0  Suburban         NaN
# 70  New Raymond          17.0  Suburban         NaN

# %%
rural_cities_df = clean_city_data_df[clean_city_data_df["type"] == "Rural"]
rural_cities_df.head()
# Out:
#                city  driver_count   type  Unnamed: 5
# 102  South Jennifer           7.0  Rural         NaN
# 103    West Heather           4.0  Rural         NaN
# 104      Newtonview           1.0  Rural         NaN
# 105     North Holly           8.0  Rural         NaN
# 106     Michaelberg           6.0  Rural         NaN

# %%
# 2. Get the total drivers for each city type
total_drivers_by_type = city_data_df.groupby(["type"]).sum()["driver_count"]
total_drivers_by_type
# Out:
# type
# Rural         78.0
# Suburban     490.0
# Urban       2405.0
# Name: driver_count, dtype: float64

# %%
#  3. Get the total amount of fares for each city type
total_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_fare_by_type = total_fares_by_type / total_rides_by_type
avg_fare_by_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type.
avg_fare_per_driver = total_fares_by_type / total_drivers_by_type
avg_fare_per_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_ride_summary_df = pd.DataFrame({
    "Total Rides": total_rides_by_type,
    "Total Drivers": total_drivers_by_type,
    "Total Fares": total_fares_by_type,
    "Average Fare per Ride": avg_fare_by_type,
    "Average Fare per Driver": avg_fare_per_driver
})

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_ride_summary_df.index.name = None
pyber_ride_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125           78.0      4327.93              34.623440
# Suburban          625          490.0     19356.33              30.970128
# Urban            1625         2405.0     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_ride_summary_df['Total Rides'] = pyber_ride_summary_df['Total Rides'].map("{:,}".format)
pyber_ride_summary_df['Total Drivers'] = pyber_ride_summary_df['Total Drivers'].map("{:,}".format)
pyber_ride_summary_df['Total Fares'] = pyber_ride_summary_df['Total Fares'].map("${:,.2f}".format)
pyber_ride_summary_df['Average Fare per Ride'] = pyber_ride_summary_df['Average Fare per Ride'].map("${:.2f}".format)
pyber_ride_summary_df['Average Fare per Driver'] = pyber_ride_summary_df['Average Fare per Driver'].map("${:.2f}".format)

pyber_ride_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125          78.0   $4,327.93                $34.62
# Suburban         625         490.0  $19,356.33                $30.97
# Urban          1,625       2,405.0  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame for reference
pyber_data_df
# Out:
#                        city             date      fare       ride_id  \
# 0        Lake Jonathanshire  1/14/2019 10:14     13.83  5.740000e+12
# 1        South Michelleport   3/4/2019 18:24     30.24  2.340000e+12
# 2        Port Samanthamouth   2/24/2019 4:29     33.44  2.010000e+12
# 3                Rodneyfort  2/10/2019 23:22     23.44  5.150000e+12
# 4                South Jack    3/6/2019 4:28     34.58  3.910000e+12
# ...                     ...              ...       ...           ...
# 1050825                 NaN              NaN  63538.64           NaN
# 1050826                 NaN              NaN  63538.64           NaN
# 1050827                 NaN              NaN  63538.64           NaN
# 1050828                 NaN              NaN  63538.64           NaN
# 1050829                 NaN              NaN  63538.64           NaN
#
#          driver_count   type  Unnamed: 5
# 0                 5.0  Urban         NaN
# 1                72.0  Urban         NaN
# 2                57.0  Urban         NaN
# 3                34.0  Urban         NaN
# 4                46.0  Urban         NaN
# ...               ...    ...         ...
# 1050825           NaN    NaN         NaN
# 1050826           NaN    NaN         NaN
# 1050827           NaN    NaN         NaN
# 1050828           NaN    NaN         NaN
# 1050829        5946.0    NaN         NaN
#
# [1050830 rows x 7 columns]

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
# use groupby({'date', 'type'}), method of aggregation is sum(), and keep 'fare' column
sum_fares_by_type = pyber_data_df.groupby(['type', 'date']).sum()['fare']
sum_fares_by_type
# Out:
# type   date
# Rural  1/1/2019 9:45      43.69
#        1/11/2019 4:39     16.42
#        1/14/2019 15:58    54.10
#        1/14/2019 7:09     18.05
#        1/15/2019 21:44    30.26
#                           ...
# Urban  5/8/2019 1:54      32.69
#        5/8/2019 2:31      41.33
#        5/8/2019 4:20      21.99
#        5/8/2019 4:39      18.45
#        5/8/2019 7:29      18.55
# Name: fare, Length: 2364, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
sum_fares_by_type_df = sum_fares_by_type.reset_index()
sum_fares_by_type_df
# Out:
#        type             date   fare
# 0     Rural    1/1/2019 9:45  43.69
# 1     Rural   1/11/2019 4:39  16.42
# 2     Rural  1/14/2019 15:58  54.10
# 3     Rural   1/14/2019 7:09  18.05
# 4     Rural  1/15/2019 21:44  30.26
# ...     ...              ...    ...
# 2359  Urban    5/8/2019 1:54  32.69
# 2360  Urban    5/8/2019 2:31  41.33
# 2361  Urban    5/8/2019 4:20  21.99
# 2362  Urban    5/8/2019 4:39  18.45
# 2363  Urban    5/8/2019 7:29  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
sum_fare_by_type_pivot = sum_fares_by_type_df.pivot(index="date", columns="type", values="fare")
sum_fare_by_type_pivot
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 5/8/2019 1:54     NaN       NaN  32.69
# 5/8/2019 2:31     NaN       NaN  41.33
# 5/8/2019 4:20     NaN       NaN  21.99
# 5/8/2019 4:39     NaN       NaN  18.45
# 5/8/2019 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fares_Jan_April = sum_fare_by_type_pivot.loc['1/1/2019':'4/28/2019']
fares_Jan_April
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 4/27/2019 6:02  38.33       NaN    NaN
# 4/27/2019 6:20    NaN     28.29    NaN
# 4/27/2019 7:18    NaN     18.56    NaN
# 4/27/2019 7:34    NaN     30.28    NaN
# 4/27/2019 8:48    NaN       NaN  12.84
#
# [2038 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
fares_Jan_April.index=pd.to_datetime(fares_Jan_April.index)
fares_Jan_April
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:00    NaN       NaN  37.91
# 2019-01-01 00:46:00    NaN     47.74    NaN
# 2019-01-01 12:32:00    NaN     25.56    NaN
# 2019-01-01 14:40:00    NaN       NaN   5.42
# 2019-01-01 14:42:00    NaN       NaN  12.31
# ...                    ...       ...    ...
# 2019-04-27 06:02:00  38.33       NaN    NaN
# 2019-04-27 06:20:00    NaN     28.29    NaN
# 2019-04-27 07:18:00    NaN     18.56    NaN
# 2019-04-27 07:34:00    NaN     30.28    NaN
# 2019-04-27 08:48:00    NaN       NaN  12.84
#
# [2038 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
fares_Jan_April.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2038 entries, 2019-01-01 00:08:00 to 2019-04-27 08:48:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     105 non-null    float64
#  1   Suburban  532 non-null    float64
#  2   Urban     1403 non-null   float64
# dtypes: float64(3)
# memory usage: 63.7 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
weekly_fares_df = fares_Jan_April.resample('W').sum()
weekly_fares_df
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  177.65    354.49   613.93
# 2019-04-14  214.60    568.47  2024.25
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1169.04  1909.51

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
#from matplotlib import style
# Use the graph style fivethirtyeight.
#style.use('fivethirtyeight')

# %%
ax = weekly_fares_df.plot(figsize=(20,5))

#title
ax.set_title("Total Fare by City Type")

#x_label
ax.set_xlabel("Month")

#y_label
ax.set_ylabel("Fare($USD)")

#save figure
plt.savefig("analysis/Fare_Summary_Plot.png")

plt.show()
